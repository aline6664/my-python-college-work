# %% [markdown]
# # Exercícios para construir programas com ENTRADA, PROCESSAMENTO e SAÍDA

# %%
n1 = 3345
n2 = 1651
resultado_da_soma = n1 * n2
resultado_da_soma
# Out:
# 5522595

# %%
numero = float( input('Digite um número: '))
type(numero)
print(numero)
# Out:
# Digite um número: 87
# 87.0

# %% [markdown]
# ### 1. Faça um programa que leia um número, multiplique ele por 2 e apresente o resultado.
#       LEIA numero
#       resultado = numero * 2
#       ESCREVA resultado

# %%
# 1º passo - identificar a(s) entrada(s) - variável número
print('*** PROGRAMA PARA MULTIPLICAR UM NÚMERO POR DOIS ***')
numero = int(input('Informe um valor......: '))

# 2º passo - identificar o processamento/cálculo
resultado = numero * 2

# 3º passo - apresentar a(s) variáveis que foram calculadas
print('A multiplicação é =',resultado)
# Out:
# *** PROGRAMA PARA MULTIPLICAR UM NÚMERO POR DOIS ***
# Informe um valor......: 7
# A multiplicação é = 14

# %% [markdown]
# ### 2. Faça um programa que:
# * receba três números inteiros
# * calcule e mostre a soma desses números.

# %%
#entrada
print('Digite 3 números quaisquer abaixo:')
n1 = int(input('Primeiro número: '))
n2 = int(input('Segundo número: '))
n3 = int(input('Terceiro número: '))

resultado = n1 + n2 + n3
print('A soma é =',resultado)
# Out:
# Digite 3 números quaisquer abaixo:
# Primeiro número: 1
# Segundo número: 2
# Terceiro número: 3
# A soma é = 6

# %% [markdown]
# ### 3. Faça um programa que receba três notas, calcule e mostre a média aritmética.

# %%
#entrada
print('MÉDIA DE NOTAS DO ALUNO')
n1 = float(input('P1: '))
n2 = float(input('P2: '))
n3 = float(input('P3: '))

resultado = (n1 + n2 + n3) / 3
print('A MÉDIA DO ALUNO É...',resultado)
# Out:
# MÉDIA DE NOTAS DO ALUNO
# P1: 8.5
# P2: 9.0
# P3: 6.5
# A MÉDIA DO ALUNO É... 8.0

# %% [markdown]
# ### 4. Faça um programa que:
# * receba o salário de um funcionário
# * calcule e mostre o novo salário, sabendo-se que este sofreu um aumento de 25%.
#
#       LEIA salario
#       novoSalario = salario + (salario * 25 / 100)
#       ESCREVA novoSalario

# %%
#entrada
print('CÁLCULO DO NOVO SALÁRIO DO FUNCIONÁRIO')
salario = float(input('Salário atual: '))
novoSalario = salario + (salario * 25 / 100)
print('Salário atualizado: ',novoSalario)
#não usa-se % para porcentagem, mas divide por 100.
# Out:
# CÁLCULO DO NOVO SALÁRIO DO FUNCIONÁRIO
# Salário atual: 1680.90
# Salário atualizado:  2101.125

# %% [markdown]
# ### 5. Faça um programa que receba o salário de um funcionário e o percentual de aumento, calcule e mostre o valor do aumento e o novo salário.

# %%
#entrada
print('CÁLCULO DE AUMENTO PERCENTUAL DO SALÁRIO')
salario = float(input('Salário atual: '))
percentual = float(input('Percentual do aumento: '))

aumento = salario * (percentual / 100)
novoSalario = salario + aumento

print('Valor do aumento: ',aumento)
print('Valor do salário: ',novoSalario)
# Out:
# CÁLCULO DE AUMENTO PERCENTUAL DO SALÁRIO
# Salário atual: 1000.00
# Percentual do aumento: 5
# Valor do aumento:  50.0
# Valor do salário:  1050.0

# %% [markdown]
# ### 6. Faça um programa que receba o salário base de um funcionário, calcule e mostre o salário a receber, sabendo-se que o funcionário tem gratificação de 5% sobre o salário base e **paga imposto** de 7% também sobre o salário base.

# %%
#entrada
salario_base = float(input('Salário do funcionário: '))
gratificacao = float(input('Gratificação percentual sobre o salário: '))
imposto = float(input('Imposto percentual pago sobre o salário: '))

salario_recebido = salario_base + (salario_base * 5 / 100) - (salario_base * 7 / 100)
print('Salário a receber: ',salario_recebido)
# Out:
# Salário do funcionário: 1000
# Gratificação percentual sobre o salário: 5
# Imposto percentual pago sobre o salário: 7
# Salário a receber:  980.0

# %% [markdown]
# ### 7. Faça um programa que receba o salário base de um funcionário, calcule e mostre seu salário a receber, sabendo-se que o funcionário tem gratificação de 50,00 sobre o salário base e **paga** imposto que deve ser lido e é aplicado sobre o salário base.
#
#     LEIA salario, perImposto
#     imposto = salario * perImposto / 100
#     salario_a_receber = salario + 50 - imposto
#     ESCREVA salario_a_receber

# %%
#entrada
salario = float(input('Salário do funcionário: '))
perImposto = float(input('Imposto percentual pago:'))
imposto = salario * perImposto / 100
salario_a_receber = salario + 50 - imposto
print('Salário a receber: ',salario_a_receber)
# Out:
# Salário do funcionário: 1580.00
# Imposto percentual pago:8
# Salário a receber:  1503.6

# %% [markdown]
# ### 8. Faça um programa que receba o valor de um depósito e o valor da taxa de juros, calcule e mostre o valor do rendimento e o valor total depois do rendimento de um mês.
#     rendimento = deposito * taxa / 100
#     total = deposito + rendimento

# %%
#entrada
deposito = float(input('Valor do depósito:'))
taxa = float(input('Valor da taxa de juros:'))

rendimento = deposito * taxa / 100
total = deposito + rendimento

print('Valor total do rendimento de um mês: ',total)
# Out:
# Valor do depósito:500
# Valor da taxa de juros:4
# Valor total do rendimento de um mês:  520.0

# %% [markdown]
# ### 9. Faça um programa que calcule e mostre a área de um triângulo. Sabe-se que: Área = (base * altura) / 2.

# %%
#entrada
print('CÁLCULO DA ÁREA DE UM TRIÂNGULO')
base = float(input('Base: '))
altura = float(input('Altura: '))
area = (base * altura) / 2
print('Área do triângulo: ',area)
# Out:
# CÁLCULO DA ÁREA DE UM TRIÂNGULO
# Base: 10
# Altura: 6.9
# Área do triângulo:  34.5

# %% [markdown]
# ### 10. Faça um programa que calcule e mostre a área de um círculo. Sabe-se que:
#     area = pi * raio² ou
#     area = 3.1415 * raio²

# %%
#entrada
print('CÁLCULO DE ÁREA DE UM CÍRCULO')
raio = float(input('Raio: '))
#processamento
pi = 3.1415
area = pi * (raio ** 2)
#saída
print(f'Área do círculo = {area:.1f}')
#pode ser feito em frase também:
print(f'A área do círculo é {area:.1f} metros quadrados.')
# Out:
# CÁLCULO DE ÁREA DE UM CÍRCULO
# Raio: 4
# Área do círculo = 50.3
# A área do círculo é 50.3 metros quadrados.

# %% [markdown]
# ### 11. Faça um programa que receba um número, calcule e mostre:
# * O número digitado ao quadrado
# * O número digitado ao cubo
# * A raiz do número digitado
# * A raiz cúbica do número digitado
#
#       LEIA numero
#       quadrado = numero ** 2
#       cubo = numero ** 3
#       raiz_quadrada = numero ** (½) (meio, ou 0.5)
#       raiz_cubica = numero ** (⅓) (um terço, ou 0.33)
#       ESCREVA quadrado, cubo, raiz_quadrada, raiz_cubica
#
#
#       raiz_quadrada = numero ** (1/2) ou
#       raiz_quadrada = numero ** 0.5

# %%
#entrada
numero = float(input('DIGITE UM NÚMERO: '))

quadrado = numero ** 2
print('Ao quadrado: ',quadrado)

cubo = numero ** 3
print('Ao cubo: ',cubo)

raiz_quadrada = numero ** 0.5
print(f'Raiz quadrada: = {raiz_quadrada:.2f}' )

raiz_cubica = numero ** 0.33
print(f'Raiz cúbica: = {raiz_cubica:.2f}')

#o f (formatação da str) aqui é utilizado para limitar casas decimais. [.xf] limita para apenas x casas depois da vírgula.
#{} são utilizados para separar variáveis
# Out:
# DIGITE UM NÚMERO: 2
# Ao quadrado:  4.0
# Ao cubo:  8.0
# Raiz quadrada: = 1.41
# Raiz cúbica: = 1.26

# %% [markdown]
# ### 12. Faça um programa que receba dois números, calcule e mostre um elevado ao outro. Use os caracteres **

# %%
#aaa
n1 = int(input('Primeiro número:' ))
n2 = int(input('Segundo número:' ))

resultado = n1 ** n2
print('Resultado: ',resultado)
# Out:
# Primeiro número:3
# Segundo número:4
# Resultado:  81

# %% [markdown]
# ### 13. Sabe-se que:
#
# * pé = 12 polegadas
# * 1 jarda = 3 pés
# * 1 milha = 1760 jarda
#
# Faça um programa que receba uma medida em pés, faça as conversões a seguir e mostre os resultados.
#
# * Polegadas;
# * Jardas;
# * Milhas.
#
#       LEIA pes
#       polegadas = pes * 12
#       jardas = pes / 3
#       milhas = jardas / 1760
#       ESCREVA polegadas, jardas, milhas

# %%
pes = float(input('Medida em pés: '))

polegadas =  pes * 12
print('Medida em polegadas: ',polegadas)

jardas = pes / 3
print(f'Medida em jardas = {jardas:.2f}')

milhas = jardas / 1760
print(f'Medida em milhas = {milhas:.2f}')
# Out:
# Medida em pés: 69.5
# Medida em polegadas:  834.0
# Medida em jardas = 23.17
# Medida em milhas = 0.01

# %% [markdown]
# ### 14. Faça um programa que receba o ano de nascimento de uma pessoa e o ano atual, calcule e mostre:
# * a idade atual da pessoa;
# * quantos anos ela terá em 2050.

# %%
ano_atual = int(input('Digite o ano atual: '))
ano_nasc = int(input('Digite seu ano de nascimento: '))

idade = ano_atual - ano_nasc
print('Idade atual: ',idade)

ano2050 = 2050 - ano_atual
idade2050 = ano2050 + idade
print('Idade em 2050: ',idade2050)
# Out:
# Digite o ano atual: 2023
# Digite seu ano de nascimento: 2005
# Idade atual:  18
# Idade em 2050:  45

# %% [markdown]
# #### 15. O custo ao consumidor de um carro novo é a soma do preço de fábrica com o percentual de lucro do distribuidor e dos impostos aplicados ao preço de fábrica. Faça um programa que receba o preço de fábrica de um veículo, o percentual de lucro do distribuidor e o percentual de impostos, calcule e mostre:
# * o valor correspondente ao lucro do distribuidor;
# * o valor correspondente aos impostos;
# * o preço final do veículo.
#         LEIA preco_fabrica
#         LEIA percentual_lucro_distribuidor
#         LEIA percentual_imposto
#         lucro_distribuidor = preco_fabrica * percentual_lucro_distribuidor / 100
#         valor_imposto = preco_fabrica * percentual_imposto / 100
#         preco_final = preco_fabrica + lucro_distribuidor + valor_imposto
#         ESCREVA lucro_distribuidor
#         ESCREVA valor_imposto
#         ESCREVA preco_final

# %%
#entrada
preco_fabrica = float(input('Preço de fábrica do veículo: '))
percentual_lucro_distribuidor = float(input('Percentual de lucro do distribuidor: '))
percentual_imposto = float(input('Percentual de impostos: '))
#processamento
lucro_distribuidor = preco_fabrica * percentual_lucro_distribuidor / 100
valor_imposto = preco_fabrica * percentual_imposto / 100
preco_final = preco_fabrica + lucro_distribuidor + valor_imposto
#saída
print('Valor correspondente ao lucro do distribuidor: ',lucro_distribuidor)
print('Valor correspondente aos impostos: ',valor_imposto)
print('Preço final do veículo: ',preco_final)
# Out:
# Preço de fábrica do veículo: 10500
# Percentual de lucro do distribuidor: 20
# Percentual de impostos: 7
# Valor correspondente ao lucro do distribuidor:  2100.0
# Valor correspondente aos impostos:  735.0
# Preço final do veículo:  13335.0

# %% [markdown]
# ### 16. Faça um programa que receba o número de horas trabalhadas e o valor do salário mínimo, calcule e mostre o salário a receber, seguindo estas regras:
# * a hora trabalhada vale a metade do salário mínimo.
# * o salário bruto equivale ao número de horas trabalhadas multiplicado pelo valor da hora trabalhada.
# * o imposto equivale a 3% do salário bruto.
# * o salário a receber equivale ao salário bruto menos o imposto.
#       LEIA qtde_horas_trabalhadas
#       LEIA valor_salario_minimo
#       valor_hora_trabalhada = valor_salario_minimo / 2
#       valor_salario_bruto = valor_hora_trabalhada * qtde_horas_trabalhadas
#       imposto = valor_salario_bruto * 3 / 100
#       valor_salario_liquido =  valor_salario_bruto - imposto
#       ESCREVA valor_salario_liquido

# %%
qtde_horas_trabalhadas = float(input('Informe a quantidade de horas trabalhadas: '))
valor_salario_minimo = float(input('Salário mínimo atual: '))

valor_hora_trabalhada = valor_salario_minimo / 2 #<- a hora trabalhada vale a metade do salário mínimo.
valor_salario_bruto = valor_hora_trabalhada * qtde_horas_trabalhadas #<- o salário bruto equivale ao número de horas trabalhadas multiplicado pelo valor da hora trabalhada.
imposto = valor_salario_bruto * 3 / 100 #<- o imposto equivale a 3% do salário bruto.
valor_salario_liquido = valor_salario_bruto - imposto #<- o salário a receber equivale ao salário bruto menos o imposto

print('Valor do salário a receber: ',valor_salario_liquido)
# Out:
# Informe a quantidade de horas trabalhadas: 8
# Salário mínimo atual: 1200
# Valor do salário a receber:  4656.0

# %% [markdown]
# ### 17. Um trabalhador recebeu seu salário e o depositou em sua conta bancária. Esse trabalhador emitiu dois cheques e agora deseja saber seu saldo atual. O banco criou uma taxa para a operação bancária de retirada que tem que pagar um imposto de 0.38% e o saldo inicial da conta está zerado.
#
#       LEIA salario
#       LEIA valor_cheque1
#       LEIA valor_cheque2
#       imposto_cheque1 = valor_cheque1 * 0.38 / 100
#       saque1 = valor_cheque1 + imposto_cheque1
#       imposto_cheque2 = valor_cheque2 * 0.38 / 100
#       saque2 = valor_cheque2 + imposto_cheque2
#       saldo = salario - saque1 - saque2
#       ESCREVA saldo

# %%
#entrada
salario = float(input('Informe seu salário: '))
valor_cheque1 = float(input('Valor do primeiro cheque: '))
valor_cheque2 = float(input('Valor do segundo cheque: '))
#processamento
imposto_cheque1 = valor_cheque1 * 0.38 / 100 #<= 38% de imposto
saque1 = valor_cheque1 + imposto_cheque1

imposto_cheque2 = valor_cheque2 * 0.38 / 100 #<= 38% de imposto
saque2 = valor_cheque2 + imposto_cheque2

saldo = salario - saque1 - saque2
#saída
print(f'Saldo atual: {saldo:.2f}')
# Out:
# Informe seu salário: 5250.80
# Valor do primeiro cheque: 20
# Valor do segundo cheque: 60
# Saldo atual: 5170.50

# %% [markdown]
# ### 18. Faça um programa que receba a medida do ângulo (em graus) formado por uma escada apoiada no chão e encostada na parede e a altura da parede onde está a ponta da escada. Calcule e mostre a medida dessa escada. Observação: as funções trigonométricas implementadas nas linguagens de programação trabalham com medidas de ângulos em radianos.
#       LEIA angulo
#       LEIA altura
#       import math # carrega a biblioteca matemática
#       radiano = angulo * math.pi / 180
#       escada = altura / math.sin(radiano)
#       ESCREVA escada
# **Observação**: Para usar seno em Python, deve-se usar esta linha de código **import math** e esta, no cálculo, **math.sin(numero)**
#
# **import math**
#
# escada = altura / **math.sin**(numero)

# %%
import math
print(f'Seno {math.sin(90):.2f}')
print(f'Cosseno {math.cos(100):.2f}')
print(f'Potência',math.pow(2,8))
print(f'Raiz Quadrada {math.sqrt(24):.2f}')
print('Pi',math.pi)
#meu deus matemática
print('Min',min(5, 10, 15))
print('Valor absoluto',abs(-7.25))
print('Potência de um valor (4*4*4)',pow(4, 3))
print('Arrendondamento maior',math.ceil(1.4))
print('Arrendondamento menor',math.floor(1.4))
# Out:
# Seno 0.89
# Cosseno 0.86
# Potência 256.0
# Raiz Quadrada 4.90
# Pi 3.141592653589793
# Min 5
# Valor absoluto 7.25
# Potência de um valor (4*4*4) 64
# Arrendondamento maior 2
# Arrendondamento menor 1

# %%
import math
#entrada
angulo = float(input('Informe a medida do ângulo (em graus) formado pela escada: '))
altura = float(input('Informe a altura da parede: '))
#processamento
radiano = angulo * math.pi / 180
escada = altura / math.sin(radiano)
#saída
print(f'A medida dessa escada é de {escada:.1f} metros.')
# Out:
# Informe a medida do ângulo (em graus) formado pela escada: 45
# Informe a altura da parede: 20
# A medida dessa escada é de 28.3 metros.

# %% [markdown]
# ###19. Sabe-se que o quilowatt de energia custa um quinto do salário mínimo. Faça um programa que receba o valor do salário mínimo e a quantidade de quilowatts consumida por uma residência. Calcule e mostre:
#
#
# * o valor de cada quilowatt;
# * o valor a ser pago por essa residência;
# * o valor a ser pago com desconto de 15%.
#       LEIA valor_salario
#       LEIA qtde_quilowatt
#       valor_quilowatt = valor_salario / 5
#       valor_em_reais = valor_quilowatt * qtde_quilowatt
#       valor_descontado = valor_em_reais * 15 / 100
#       valor_com_desconto =  valor_em_reais − valor_descontado
#       ESCREVA valor_quilowatt
#       ESCREVA valor_em_reais
#       ESCREVA valor_com_desconto

# %%
#entrada
valor_salario = float(input('Informe o valor do salário mínimo atual: '))
qtde_quilowatt = float(input('Informe a quantidade de quilowatts consumida por sua residência: '))
#processamento
print() #<- print vazio pode ser usado como espaço
valor_quilowatt = valor_salario / 5 #<- um quinto do valor
valor_em_reais = valor_quilowatt * qtde_quilowatt 
valor_descontado = valor_em_reais * 15 / 100 #<- 15% de desconto
valor_com_desconto = valor_em_reais - valor_descontado
#saída
print('Valor de cada quilowatt: ',valor_quilowatt)
print('Valor a ser pago por sua residência: ',valor_em_reais)
print('Valor a ser pago com desconto de 15%: ',valor_com_desconto)
# Out:
# Informe o valor do salário mínimo atual: 1200
# Informe a quantidade de quilowatts consumida por sua residência: 10
#
# Valor de cada quilowatt:  240.0
# Valor a ser pago por sua residência:  2400.0
# Valor a ser pago com desconto de 15%:  2040.0

# %% [markdown]
# ### 20. Faça um programa que receba um número real, encontre e mostre:
#
# * a parte inteira desse número;
# * a parte fracionária desse número;
# * o arredondamento desse número.
#
#       LEIA numero
#       parte_inteira = numero // 1
#       parte_fracionaria = numero - parte_inteira
#       numero_arredondado = round (numero)
#       ESCREVA parte_inteira
#       ESCREVA parte_fracionaria
#       ESCREVA numero_arredondado
#
# **Observação**: Para arredondar um número em Python, usa-se a função **round(numero)**, onde se o número real/float estiver em igual distância entre o inteiro de cima e o inteiro de baixo, esta função arredonda para o número mais próximo.

# %%
#entrada
numero = float(input('Digite um número real: '))
#processamento
parte_int = numero // 1 #<- pega a parte inteira e ignora as casas decimais
parte_frac = numero - parte_int
numero_arredondado = round (numero) #<- arredonda
#saída
print('A parte inteira desse número: ',parte_int)
print(f'A parte fracionário desse número: {parte_frac:.3f}')
print('O arredondamento desse número: ',numero_arredondado)
# Out:
# Digite um número real: 18.567
# A parte inteira desse número:  18.0
# A parte fracionário desse número: 0.567
# O arredondamento desse número:  19

# %% [markdown]
# ### 21. Faça um programa que receba uma hora formada por hora e minutos (um número real), calcule e mostre a hora digitada apenas em minutos. Lembre-se de que:
# * para quatro e meia, deve-se digitar 4.30;
# * os minutos vão de 0 a 59.
#       LEIA hora
#       h = pegar a parte inteira da variável hora
#       minutos = hora − h
#       conversao = (h * 60) + (minutos * 100)
#       ESCREVA conversao

# %%
#entrada
hora = float(input('Informe a hora: '))
#processamento
h = hora // 1 #<- por dividir por 1, resulta em nele mesmo mas tira as casas decimais (pegando apenas a hora)
print(h)

minutos = hora - h
print(f'{minutos: .2f}')

conversao = (h * 60) + (minutos * 100)
#saída
print(f'Hora em minutos: = {conversao: .2f}')
# Out:
# Informe a hora: 9.16
# 9.0
#  0.16
# Hora em minutos: =  556.00

# %% [markdown]
# ### 22. Faça um programa que receba o custo de um espetáculo teatral e o preço do convite desse espetáculo. Esse programa deverá calcular e mostrar a quantidade de convites que devem ser vendidos para que, pelo menos, o custo do espetáculo seja alcançado.

# %%
custo_esp = float(input('Custo do espetáculo teatral: '))
preco_conv = float(input('Preço do convite do espetáculo: '))

quant_conv = custo_esp / preco_conv
print('Quantidade de convites que devem ser vendidos: ',quant_conv)
# Out:
# Custo do espetáculo teatral: 5000
# Preço do convite do espetáculo: 2.50
# Quantidade de convites que devem ser vendidos:  2000.0
