# %% [markdown]
# #**EXERCÍCIOS SOBRE VETOR**

# %% [markdown]
# ### 1. Faça um programa que calcule e apresente a média de idades de uma sala de 35 alunos.​​

# %%
i = 0
idade = []
soma_idades = 0
while i < 5:
    idade.append(int(input('Digite a idade: ')))
    soma_idades = soma_idades + idade[i]
    i = i + 1
if i > 0:
    media = soma_idades / i
    print(f'A média de idades é...{media:.2f} anos')
# Out:
# Digite a idade: 12
# Digite a idade: 25
# Digite a idade: 21
# Digite a idade: 14
# Digite a idade: 27
# A média de idades é...19.80 anos

# %% [markdown]
# ### 2. Faça um programa que calcule e apresente a média de alturas de uma sala de 35 alunos. Informe também quantos alunos **e** quais (índice/posição) são os que possuem idade superior a 25 anos.​ Use dois vetores, um para altura e outro para idade. Não use nenhuma função pronta da linguagem Python, a não ser len() e append().

# %%
idade = []
altura = []
soma_alturas = 0
qtde_alunos = 0

for i in range(3):
      idade.append(int(input('Digite a idade: ' )))
      altura.append(float(input('Digite a altura: ' )))
      soma_alturas = soma_alturas + altura[i]
media = soma_alturas / len(altura) # <- len irá mostrar a quantidade exata de números que foi inserido no vetor. É preferível a colocar a quantidade "3" sozinha.
print(f'Média = {media:.2f} metros.')

for i in range(len(idade)):
      if idade[i] > 25:
            qtde_alunos = qtde_alunos + 1
            print(f'Aluno nº {i}, possui {idade[i]} anos.')
print('Quantidade de alunos com mais de 25 anos: ',qtde_alunos)
# Out:
# Digite a idade: 35
# Digite a altura: 1.89
# Digite a idade: 27
# Digite a altura: 1.74
# Digite a idade: 18
# Digite a altura: 1.69
# Média = 1.77 metros.
# Aluno nº 0, possui 35 anos.
# Aluno nº 1, possui 27 anos.
# Quantidade de alunos com mais de 25 anos:  2

# %% [markdown]
# ### 3. Faça um programa que carregue um vetor de dez elementos que contenha o nome de pessoas e outro que contenha o peso, encontre qual a pessoa mais gorda e mais magra e apresente o nome o peso das mesmas.​ Use dois vetores, um para peso e outro para nome. Não use nenhuma função pronta da linguagem Python, a não ser len() e append().

# %%
nome = []
peso = []

for i in range(3):
    nome.append(input('Digite o nome: ')) # (º_º)
    peso.append(float(input('Informe o peso: ')))
    if i == 0: # <- hora que iniciar... este if é apenas executado UMA vez, para realizar os valores comparativos
        gorda = peso[i] # peso que foi digitado a primeira vez
        nomea = nome[i]
        magra = peso[i]
        nomeb = nome[i]
    if peso[i] > gorda:
        gorda = peso[i]
        nomea = nome[i]
    elif peso[i] < magra:
        magra = peso[i]
        nomeb = nome[i]
print(nomea,f'é a pessoa mais gorda, com',gorda,'kg e',nomeb,f'a pessoa mais magra, com',magra,'kg.')
# Out:
# Digite o nome: Ana
# Informe o peso: 67
# Digite o nome: Bia
# Informe o peso: 53
# Digite o nome: Carla
# Informe o peso: 48
# Ana é a pessoa mais gorda, com 67.0 kg e Carla a pessoa mais magra, com 48.0 kg.

# %%
# Lógica de encontrar valores maiores ou menores sem usar vetor. São mesmas situações.

for pessoas in range(5):
    altura = float(input('Informe a altura: '))
    nome = input('Informe o nome: ')
    if pessoas == 0:
        alto = altura
        nomea = nome
        baixo = altura
        nomeb = nome
    if altura >= alto:
        alto = altura
        nomea = nome
    elif altura <= baixo:
        baixo = altura
        nomeb = nome
print(nomea,'é mais alto, com',alto,'metros')
print(nomeb,'é mais baixo, com',baixo,'metros')

# %% [markdown]
# ### 4. Faça um programa que carregue um vetor com a média de dez alunos, calcule e mostre a MÉDIA DA SALA e quantos alunos estão acima e abaixo da média da sala. Não use nenhuma função pronta da linguagem Python, a não ser len() e append().

# %%
media = []
soma_media = 0
soma_aluno_abaixo = 0
soma_aluno_acima = 0

for i in range(5):
    media.append(float(input('Digite a média do aluno: ')))
    soma_media = soma_media + media[i]

media_sala = soma_media / len(media)
print('Média da sala:.......',media_sala)

for i in range(len(media)):
    if media[i] < media_sala:
        soma_aluno_abaixo = soma_aluno_abaixo + 1
    else:
        soma_aluno_acima = soma_aluno_acima + 1

print('Há',soma_aluno_acima,'aluno(s) acima da média e',soma_aluno_abaixo, 'aluno(s) abaixo da média')
# Out:
# Digite a média do aluno: 9.5
# Digite a média do aluno: 7.5
# Digite a média do aluno: 5.5
# Digite a média do aluno: 7.0
# Digite a média do aluno: 8.0
# Média da sala:....... 7.5
# Há 3 aluno(s) acima da média e 2 aluno(s) abaixo da média

# %% [markdown]
# ### 5. Faça um programa que carregue um vetor de oito elementos numéricos inteiros, calcule e mostre os números pares e suas respectivas índices/posições. Não use nenhuma função pronta da linguagem Python, a não ser len() e append().

# %%
numero = []

for i in range(8):
    numero.append(int(input('Digite um elemento numérico: ')))
    if numero[i] % 2 == 0:
        print(f'Número par, posição nº {i}')
# Out:
# Digite um elemento numérico: 35
# Digite um elemento numérico: 68
# Número par, posição nº 1
# Digite um elemento numérico: 68
# Número par, posição nº 2
# Digite um elemento numérico: 26
# Número par, posição nº 3
# Digite um elemento numérico: 1
# Digite um elemento numérico: 23
# Digite um elemento numérico: 54
# Número par, posição nº 6
# Digite um elemento numérico: 4
# Número par, posição nº 7

# %% [markdown]
# ### 6. Faça um programa que carregue um vetor com dez nomes e faça uma verificação se um determinado nome esta nesse vetor. Não use nenhuma função pronta da linguagem Python, a não ser len() e append().

# %%
nome = []

for i in range(4):
    nome.append(input('Digite o nome: '))

verif = input('Verifique se o nome está nesse vetor: ')
for i in range(len(nome)):
    if verif == nome[i]:
        print('O nome está determinado nesse vetor.')
# Out:
# Digite o nome: Amanda
# Digite o nome: João
# Digite o nome: Pedro
# Digite o nome: Sandra
# Verifique se o nome está nesse vetor: Pedro
# O nome está determinado nesse vetor.

# %% [markdown]
# ### 7. Faça um algoritmo que calcule e apresente a média de alturas superior a 1,80 de 10 alunos. Informe também quantos e quais (índice/posição) são os alunos. Não use nenhuma função pronta da linguagem Python, a não ser len() e append().

# %%
altura = []
alto = [] # maiores de 1.80
soma_altura = 0

for i in range(5):
    altura.append(float(input('Informe a altura: ')))
    if altura[i] > 1.80:
        alto.append(numero[i])
        soma_altura = soma_altura + altura[i]

print('Soma: ',soma_altura)
print()
for i in range(len(alto)):
    print('Quantidade de alunos: ',len(alto))
    print('Índice dos alunos: ',alto[i])

media = soma_altura / len(alto)
print('Média de alturas superior a 1,80: ',media)
# Out:
# Informe a altura: 1.98
# Soma:  1.98
# Informe a altura: 1.81
# Soma:  3.79
# Informe a altura: 1.67
# Informe a altura: 1.92
# Soma:  5.71
# Informe a altura: 1.87
# Soma:  7.58
#
# Quantidade de alunos:  4
# Índice dos alunos:  5
# Quantidade de alunos:  4
# Índice dos alunos:  16
# Quantidade de alunos:  4
# Índice dos alunos:  43
# Quantidade de alunos:  4
# Índice dos alunos:  -72
# Média de alturas superior a 1,80:  1.895

# %% [markdown]
# ### 8. Criar um algoritmo que a partir de um vetor de 10 elementos inteiros, crie outros dois vetores que receberão os elementos positivos e negativos e ao final apresente-os. Não use nenhuma função pronta da linguagem Python, a não ser len() e append().

# %%
numero = []
positivo = []
negativo = []
for i in range(5):
    numero.append(int(input('Digite um número: ')))
    if numero[i] >= 0:
        positivo.append(numero[i])
    else:
        negativo.append(numero[i])
print(positivo)
print(negativo)
print('Apresentação dos valores positivos..............')
for i in range(len(positivo)):
    print('Índice:',i,'\nElemento do vetor positivo:',positivo[i])
print('Apresentação dos valores negativos..............')
for i in range(len(negativo)):
    print('Índice:',i,'\nElemento do vetor negativo:',negativo[i])
# Out:
# Digite um número: 5
# Digite um número: 16
# Digite um número: -17
# Digite um número: 43
# Digite um número: -72
# [5, 16, 43]
# [-17, -72]
# Apresentação dos valores positivos..............
# Índice: 0
# Elemento do vetor positivo: 5
# Índice: 1
# Elemento do vetor positivo: 16
# Índice: 2
# Elemento do vetor positivo: 43
# Apresentação dos valores negativos..............
# Índice: 0
# Elemento do vetor negativo: -17
# Índice: 1
# Elemento do vetor negativo: -72

# %% [markdown]
# ### 9. Criar um algoritmo que leia dados para um vetor de 100 elementos inteiros, imprimir o maior, o menor, o percentual de números pares e a média dos elementos do vetor. Obs.: percentual = quantidade contada * 100 / quantidade total. Não use nenhuma função pronta da linguagem Python, a não ser len() e append().

# %%
numero = []
par = []
soma_total = 0
soma_par = 0

for i in range(5):
    numero.append(int(input('Valor: ')))
    soma_total = soma_total + numero[i]
    if i == 0:
        maior = numero[i]
        menor = numero[i]
    if numero[i] >= maior:
        maior = numero[i]
        if numero[i] % 2 == 0:
            soma_par = soma_par + 1
    elif numero[i] <= menor:
        menor = numero[i]
        if numero[i] % 2 == 0:
            soma_par = soma_par + 1

percentual = soma_par * 100 / len(numero)
media = soma_total / len(numero)
print('\nDados:.........................')
print('Maior número: ',maior)
print('Menor número: ',menor)
print('Percentual de números pares: ',percentual)
print('Média dos elementos: ',media)
# Out:
# Valor: 20
# Valor: 52
# Valor: 71
# Valor: 35
# Valor: 14
#
# Dados:.........................
# Maior número:  71
# Menor número:  14
# Percentual de números pares:  60.0
# Média dos elementos:  38.4
# []

# %%
nome = []
peso = []

for i in range(3):
    nome.append(input('Digite o nome: ')) # (º_º)
    peso.append(float(input('Informe o peso: ')))
    if i == 0: # <- hora que iniciar... este if é apenas executado UMA vez, para realizar os valores comparativos
        gorda = peso[i] # peso que foi digitado a primeira vez
        nomea = nome[i]
        magra = peso[i]
        nomeb = nome[i]
    if peso[i] > gorda:
        gorda = peso[i]
        nomea = nome[i]
    elif peso[i] < magra:
        magra = peso[i]
        nomeb = nome[i]
print(nomea,f'é a pessoa mais gorda, com',gorda,'kg e',nomeb,f'a pessoa mais magra, com',magra,'kg.')

# %% [markdown]
# ### 10. Faça um programa que:
#
# * preencha um vetor com seis elementos numéricos inteiros.
#
# **Calcule e mostre:**
#
# * todos os números pares;
# * a quantidade de números pares;
# * todos os números ímpares;
# * a quantidade de números ímpares
#
# Não use nenhuma função pronta da linguagem Python, a não ser len() e append().

# %%
# Digite seu código aqui. øøø▓♫☼►♀♪♀☼Éø♂○xc♠♥☻☺▬☻☻☻☻☻☻▓│♫8▬^mUb7M♠:╝+○X▄Æm»øÉØY15741├☼>f
numero = []
par = []
impar = []
soma_par = 0
soma_impar = 0

for i in range(6):
    numero.append(int(input('Elemento númerico: ')))
    if numero[i] % 2 == 0:
        par.append(numero[i])
        soma_par = soma_par + 1
    else:
        impar.append(numero[i])
        soma_impar = soma_impar + 1
        
print('Números pares: ',par,'\nQuantidade de pares: ',soma_par)
print('Números ímpares: ',impar,'\nQuantidade de ímpares: ',soma_impar)
# Out:
# Elemento númerico: 46
# Elemento númerico: 91
# Elemento númerico: 32
# Elemento númerico: 40
# Elemento númerico: 57
# Elemento númerico: 24
# Números pares:  [46, 32, 40, 24]
# Quantidade de pares:  4
# Números ímpares:  [91, 57]
# Quantidade de ímpares:  2

# %% [markdown]
# ### 11. Faça um programa que:
#
# * preencha um vetor com sete números inteiros
#
# **Calcule e mostre:**
#
# * os números múltiplos de 2;
# * os números múltiplos de 3;
# * os números múltiplos de 2 **e de** 3.
#
# Não use nenhuma função pronta da linguagem Python, a não ser len() e append().

# %%
numero = []
multiplo_2 = []
multiplo_3 = []
multiplo_2_e_3 = []

for i in range(7):
    numero.append(int(input('Elemento númerico: ')))
    if numero[i] % 2 == 0:
        multiplo_2.append(numero[i])
        if numero[i] % 3 == 0
                multiplo_2_e_3.append(numero[i])
    elif numero[i] % 3 == 0:
        multiplo_3.append(numero[i])

print('Números múltiplos de 2: ',multiplo_2)
print('Números múltiplos de 3: ',multiplo_3)
print('Números múltiplos de 2 e de 3: ',multiplo_2_e_3)
# Out:
# Elemento númerico: 23
# Elemento númerico: 20
# Elemento númerico: 27
# Elemento númerico: 42
# Elemento númerico: 18
# Elemento númerico: 12
# Elemento númerico: 3
# Números múltiplos de 2:  [20, 42, 18, 12]
# Números múltiplos de 3:  [27, 3]
# Números múltiplos de 2 e de 3:  [42, 18, 12]

# %% [markdown]
# ### 12. Faça um programa que:
#
# * preencha um vetor com quinze elementos inteiros
# * verifique a existência de elementos iguais a 30, mostrando os índices/posições em que apareceram.
#
# Não use nenhuma função pronta da linguagem Python, a não ser len() e append().

# %%
numero = []
for i in range(5):
    numero.append(int(input('Número: ')))
    if numero[i] == 30:
        print('Existência de elemento igual a 30 verificado. Posição: ',i)
# Out:
# Número: 34
# Número: 30
# Existência de elemento igual a 30 verificado. Posição:  1
# Número: 14
# Número: 5
# Número: 30
# Existência de elemento igual a 30 verificado. Posição:  4

# %% [markdown]
# ### 13. Faça um programa que:
#
# * preencha um vetor com dez números reais
#
# **Calcule e mostre:**
#
# * a quantidade de números negativos
# * a soma dos números positivos desse *vetor*
# * não use nenhuma função pronta da linguagem Python

# %%
numero = []
qtd_negativo = 0
soma_positivo = 0

for i in range(10):
    numero.append(float(input('Número: ')))
    if numero[i] < 0:
        qtd_negativo = qtd_negativo + 1
    else:
        soma_positivo = soma_positivo + numero[i]
print('Quantidade de números negativos: ',qtd_negativo)
print('Soma de números positivos: ',soma_positivo)
# Out:
# Número: 67
# Número: -42
# Número: 1
# Número: 45
# Número: -4
# Número: -7
# Número: 42
# Número: -78
# Número: -4
# Número: -13
# Quantidade de números negativos:  6
# Soma de números positivos:  155.0

# %% [markdown]
# ### 14. Faça um programa que:
#
# * receba dez números inteiros e armazene-os em um vetor
# * classifique os números em dois vetores, um com números pares e o outra com os ímpares
#
# Não use nenhuma função pronta da linguagem Python, a não ser len() e append().

# %%
numero = []
par = []
impar = []

for i in range(10):
    numero.append(int(input('Número: ')))
    if numero[i] % 2 == 0:
        par.append(numero[i])
    else:
        impar.append(numero[i])
print('Números pares: ',par)
print('Números ímpares: ',impar)
# Out:
# Número: 22
# Número: 17
# Número: 64
# Número: 12
# Número: 76
# Número: 19
# Número: 72
# Número: 3
# Número: 45
# Número: 79
# Números pares:  [22, 64, 12, 76, 72]
# Números ímpares:  [17, 19, 3, 45, 79]

# %% [markdown]
# ### 15. Faça um programa que:
#
# * preencha um vetor com quinze números
#
# **Determine e mostre:**
#
# * o maior número e a posição por ele ocupada no vetor
# * o menor número e a posição por ele ocupada no vetor
#
# Não use nenhuma função pronta da linguagem Python, a não ser len() e append().

# %%
numero = []

for i in range(5):
    numero.append(int(input('Número: ')))
    if i == 0:
        maior = numero[i]
        i_maior = i
        menor = numero[i]
        i_menor = i
    if numero[i] >= maior:
        maior = numero[i]
        i_maior = i
    elif numero[i] <= menor:
        menor = numero[i]   
        i_menor = i     

print('Maior número: ',maior,'\tPosição: ',i_maior)
print('Menor número: ',menor,'\tPosição: ',i_menor)
# Out:
# Número: 14
# Número: 38
# Número: 29
# Número: 64
# Número: 12
# Maior número:  64 	Posição:  3
# Menor número:  12 	Posição:  4

# %% [markdown]
# ### 16. Faça um programa que:
#
# * preencha dois vetores com de dez numeros cada
# * preencha um terceiro vetor com os números dos dois vetores anteriores ordenados em ordem crescente

# %%
vetor1 = []
vetor2 = []
vetor3 = []

for i in range(3):
    vetor1.append(int(input('Número [1º vetor]: ')))
    vetor3.append(vetor1[i])
print(vetor1)
print()

for i in range(3):
    vetor2.append(int(input('Número [2º vetor]: ')))
    vetor3.append(vetor2[i])
print(vetor2)
print()

print(vetor3)

# ORDENAR EM ORDEM CRESCENTE
# Out:
# Número [1º vetor]: 45
# Número [1º vetor]: 73
# Número [1º vetor]: 42
# [45, 73, 42]
#
# Número [2º vetor]: 57
# Número [2º vetor]: 83
# Número [2º vetor]: 12
# [57, 83, 12]
#
# [45, 73, 42, 57, 83, 12]

# %% [markdown]
# ### 17. Faça um programa que:
#
# * carregue dois vetores com 10 números cada
# * faça a multiplicação dos números na mesma posição
# * o resultado deverá ser adicionada em um terceiro vetor
#
# Não use nenhuma função pronta da linguagem Python, a não ser len() e append().

# %%
a = []
b = []
c = []

for ai in range(3):
    a.append(int(input('Número: ')))
for bi in range(3):
    b.append(int(input('Número: ')))
if ai == bi:
    produto = a[i] * b[i]
    c.append(produto)

print(c)

# a [ 8, 6, 3, 5]
# b [ 3, 2, 9, 2]
# c [8*3, 6*2,3*9, 5*2]
# c [24, 12, 27, 10]
# Out:
# Número: 5
# Número: 1
# Número: 3
# Número: 4
# Número: 7
# Número: 2
# [6]

# %% [markdown]
# ### 18. Faça um programa que:
#
# * leia um vetor de 10 números inteiros
# * exiba na tela os números positivos e seus respectivos índices.
#
# Não use nenhuma função pronta da linguagem Python, a não ser len() e append().

# %%
numero = []
positivo = []
indice = []

for i in range(5):
    numero.append(int(input('Número: ')))
    if numero[i] >= 0:
        positivo.append(numero[i])
        indice.append(i)
print('Números positivos: ',positivo)
print('Índices: ',indice)
# Out:
# Número: -10
# Número: 23
# Número: 7
# Número: -21
# Número: 3
# Números positivos:  [23, 7, 3]
# Índices:  [1, 2, 4]

# %% [markdown]
# ### 19. Faça um programa que:
#
# * insira dez números inteiros em um vetor
# * crie um segundo vetor, substituindo os números multiplos de 3 por "999""
# * exiba os dois vetores
#
# Não use nenhuma função pronta da linguagem Python, a não ser len() e append().

# %%
vetor1 = []
vetor2 = []

for i in range(5):
    vetor1.append(int(input('Número: ')))

for i in range(len(vetor1)):
    vetor2.append(vetor1[i])
    if vetor2[i] % 3 == 0:
        vetor2[i] = 999

print('Primeiro vetor: ',vetor1)
print('Segundo vetor: ',vetor2)
# Out:
# Número: 13
# Número: 30
# Número: 22
# Número: 18
# Número: 21
# Primeiro vetor:  [13, 30, 22, 18, 21]
# Segundo vetor:  [13, 999, 22, 999, 999]

# %% [markdown]
# ### 20. Faça um programa que:
#
# * leia dois vetores (A e B) com cinco posições para números inteiros.
# * o programa deve, então, subtrair o primeiro elemento de A do último de B, armazenando o resultado num terceiro vetor, subtrair o segundo elemento de A do penúltimo de B, armazenando o resultado num terceiro vetor e assim por diante.
# * ao final, mostre o resultado do terceiro vetor
#
# O índice de um dos vetores terá que ser decrementado (slide 2 de Vetor) , ou seja, você implementara ele manualmente.
#
# Não use nenhuma função pronta da linguagem Python, a não ser len() e append().

# %%
A = []
B = []
C = []

for i in range(5):
    A.append(int(input('Digite um valor para o vetor A: ')))
    B.append(int(input('Digite um valor para o vetor B: ')))

p = len(A) - 1 # p começa do último índice (4)
for i in range(len(A)): # pode ser B também pois ambos são iguais.
    C.append(A[i] - B[p])
    p = p - 1 # realiza decremento (do último índice para o primeiro)

print(A)
print(B)
print(C)
# Out:
# Digite um valor para o vetor A: 45
# Digite um valor para o vetor B: 74
# Digite um valor para o vetor A: 85
# Digite um valor para o vetor B: 13
# Digite um valor para o vetor A: 25
# Digite um valor para o vetor B: 46
# Digite um valor para o vetor A: 23
# Digite um valor para o vetor B: 45
# Digite um valor para o vetor A: 23
# Digite um valor para o vetor B: 34
# [45, 85, 25, 23, 23]
# [74, 13, 46, 45, 34]
# [11, 40, -21, 10, -51]

# %% [markdown]
# ###21. Faça um programa que:
#
# * preencha um vetor de cinco números e mostre a saída a seguir:
# * imprima a seguinte saída, exemplo (cada número e o sinal de adição e depois o resultado da soma dos números) 8 + 2 + 1 + 3 + 0 = 14
#
# Não use nenhuma função pronta da linguagem Python, a não ser len() e append().

# %%
A = []
soma = 0

for i in range(5):
    A.append(int(input('Digite um número: ')))
    soma = soma + A[i]

print(A[0],'+',A[1],'+',A[2],'+',A[3],'+',A[4],'=',soma)
# Out:
# Digite um número: 5
# Digite um número: 7
# Digite um número: 8
# Digite um número: 2
# Digite um número: 4
# 5 + 7 + 8 + 2 + 4 = 26

# %% [markdown]
# ### 22. Faça um programa que:
# * leia um vetor com quinze posições para números inteiros.
# * depois da leitura, em outro vetor, armazene a divisão de todos os  elementos pelo maior valor do vetor, para isso encontre o maior elemento
# * Mostre o vetor após os cálculos.
#
# Não use nenhuma função pronta da linguagem Python, a não ser len() e append().

# %%
A = []
B = []
maior = 0

for i in range(5):
    A.append(int(input('Digite um número: ')))
    if A[i] > maior:
        maior = A[i]

for i in range(len(A)):
    B.append(A[i] / maior)

print(A)
print(B)
# Out:
# Digite um número: 72
# Digite um número: 38
# Digite um número: 67
# Digite um número: 48
# Digite um número: 50
# [72, 38, 67, 48, 50]
# [1.0, 0.5277777777777778, 0.9305555555555556, 0.6666666666666666, 0.6944444444444444]

# %% [markdown]
# ### 23. Um vetor é palíndromo se ele não se alterar quando o mesmo for invertido. Escreva um programa que verifique se um vetor é palíndromo, fazendo comparação de índice/posição por índice/posição do vetor original (vo) com o vetor invertido (vi). Não use nenhuma função pronta da linguagem Python. A tamanho do vetor pode ser da sua escolha.
# Exemplo:
# vetor original    vo = {1, 3, 5, 2, 2, 5, 3, 1}
# vetor invertido é vi = {1, 3, 5, 2, 2, 5, 3, 1}
# O vetor invertido **é palíndromo**, pois ele invertido é igual ao original
#
# vetor original    vo = {9, 7, 5, 2, 4, 5, 3, 6}
# vetor invertido é vi = {6, 3, 5, 4, 2, 5, 7, 9}
# O vetor invertido **não é palíndromo**, pois ele invertido é igual ao original

# %%
vo = []
vi = []

for i in range(8):
    vo.append(int(input('Digite um número: ')))
print(vo)

p = len(vo) - 1
for i in range(len(vo)):
    vi.append(vo[p])
    p = p - 1
print(vi)

if vo[i] == vi[i]:
    print('O vetor invertido é palíndromo.')
else:
    print('O vetor invertido não é palíndromo.')
# Out:
# Digite um número: 1
# Digite um número: 4
# Digite um número: 5
# Digite um número: 7
# Digite um número: 8
# Digite um número: 5
# Digite um número: 3
# Digite um número: 4
# [1, 4, 5, 7, 8, 5, 3, 4]
# [4, 3, 5, 8, 7, 5, 4, 1]
# O vetor invertido não é palíndromo.

# %%
vo = []
vi = []

for i in range(8):
    vo.append(int(input('Digite um número: ')))
print(vo)

p = len(vo) - 1
for i in range(len(vo)):
    vi.append(vo[p])
    p = p - 1
print(vi)

if vo[i] == vi[i]:
    print('O vetor invertido é palíndromo.')
else:
    print('O vetor invertido não é palíndromo.')
# Out:
# Digite um número: 1
# Digite um número: 3
# Digite um número: 5
# Digite um número: 2
# Digite um número: 2
# Digite um número: 5
# Digite um número: 3
# Digite um número: 1
# [1, 3, 5, 2, 2, 5, 3, 1]
# [1, 3, 5, 2, 2, 5, 3, 1]
# O vetor invertido é palíndromo.
